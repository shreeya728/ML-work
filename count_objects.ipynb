# %% [markdown]
# <a href="https://colab.research.google.com/github/shreeya728/ML-work/blob/main/count_objects.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2
import cvlib as cv

# %%
# !pip install cvlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 88.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cvlib: filename=cvlib-0.2.7-py3-none-any.whl size=10046368 sha256=820e3fa5ae4b1406ea44de1669b8c5d210663e8b87fbf0aa48ea4864f4db4244
#   Stored in directory: /root/.cache/pip/wheels/9e/a5/d4/fe37b48fe4f4b621ba5e574a991230070f3cc4f02322a01489
# ...
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12067 sha256=f2739ea70b879198412dad960de6eafda9114f3a083b33cfc9de10861ba6bb6d
#   Stored in directory: /root/.cache/pip/wheels/cd/17/e5/765d1a3112ff3978f70223502f6047e06c43a24d7c5f8ff95b
# Successfully built cvlib progressbar
# ...

# %%
from cvlib.object_detection import draw_bbox
from numpy.lib.polynomial import poly

# %% [markdown]
# This is my first try with python.

# %%
import matplotlib.pyplot as plt
image = cv2.imread("cars.png")
box, label, count = cv.detect_common_objects(image)
output = draw_bbox(image, box, label, count)
plt.imshow(output)
plt.show()
print("Number of cars in this image are "+str(label.count('car')))
# Out:
#   0% |                                                                        |
# ...
# Number of cars in this image are 11
